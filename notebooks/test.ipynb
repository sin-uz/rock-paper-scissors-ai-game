# %%
import cv2
from hand_detector import HandDetector
from visualizer import AnnotationsVisualizer
from gesture_classifier import VectorBasedClassifier
from game_logic.game_controller import GameController

# %%
mirror_display = True

cap = cv2.VideoCapture(1)

visualizer = AnnotationsVisualizer()
classifier = VectorBasedClassifier(straightening_threshold=0.5)
game_controller = GameController(classifier)

try:

    with HandDetector(
        user_perspective=True,
        static_image_mode=False,
        max_num_hands=2,
        min_detection_confidence=0.7,
        min_tracking_confidence=0.7   
    ) as detector:
        
        print("Gra uruchomiona! Pokaz kciuk w gore aby zaczac.")
        print("Nacisnij ESC aby wyjsc.")
        
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                break
            
            detected_hands = detector.detect(frame)
            
            game_controller.update(detected_hands)
            
            frame_to_show = cv2.flip(frame, 1) if mirror_display else frame
            
            frame_to_show = visualizer.render(
                frame_to_show, detected_hands, mirror_display)
            
            frame_to_show = game_controller.render_ui(frame_to_show)
            
            cv2.imshow("Rock Paper Scissors AI Game", frame_to_show)
            
            key = cv2.waitKey(1) & 0xFF
            if key == 27:
                break
            
            if key == ord('r') or key == ord('R'):
                game_controller.reset()
                print("Gra zresetowana!")
                
finally:
    cap.release()
    cv2.destroyAllWindows()
    print("\nGra zakonczona!")
    print(f"Wynik koncowy: Gracz {game_controller.player_score} - {game_controller.computer_score} Komputer")
# Out:
# Gra uruchomiona! Pokaz kciuk w gore aby zaczac.
# Nacisnij ESC aby wyjsc.
# d:\Resources\Projects\DeepLearning\mp_env\lib\site-packages\google\protobuf\symbol_database.py:55: UserWarning: SymbolDatabase.GetPrototype() is deprecated. Please use message_factory.GetMessageClass() instead. SymbolDatabase.GetPrototype() will be removed soon.
#   warnings.warn('SymbolDatabase.GetPrototype() is deprecated. Please '
# Vectors: (array([ 0.01567119, -0.01952606, -0.01958806,  0.02088463, -0.02840275,
#        -0.02437196]), array([ 0.05748874,  0.00965637, -0.02059074, -0.00281891,  0.00826257,
#        -0.00369818]), array([ 0.05844578,  0.0108971 , -0.01198833, -0.02435338, -0.0090121 ,
#         0.01913795]), array([ 0.050924  ,  0.00185168, -0.00385974, -0.0191026 , -0.01060414,
#         0.01818897]))
# Prodcuts: (np.float64(0.998), np.float64(-0.01), np.float64(-0.895), np.float64(-0.731))
# States: (True, False, False, False)
# Vectors: (array([ 0.01577944, -0.01998997, -0.02054109,  0.01904973, -0.02961737,
#        -0.02488795]), array([ 0.05773759,  0.01036638, -0.02146135, -0.00436306,  0.00630534,
#        -0.00345515]), array([ 0.05890003,  0.01117742, -0.01246036, -0.0251877 , -0.00957149,
#         0.02020766]), array([ 0.0512425 ,  0.0026052 , -0.00426424, -0.02008051, -0.01116931,
#         0.01840129]))
# Prodcuts: (np.float64(0.995), np.float64(-0.214), np.float64(-0.893), np.float64(-0.75))
# States: (True, False, False, False)
# Vectors: (array([ 0.01653525, -0.01956332, -0.02155154,  0.02002984, -0.02871102,
#        -0.02552224]), array([ 0.057291  ,  0.01170766, -0.02176806, -0.00187019,  0.00552785,
#        -0.00257798]), array([ 0.05942854,  0.01370859, -0.01204949, -0.02527586, -0.01164186,
#         0.02206138]), array([ 0.05187175,  0.00426131, -0.00436371, -0.01895255, -0.01375633,
#         0.01888478]))
# Prodcuts: (np.float64(0.995), np.float64(0.034), np.float64(-0.873), np.float64(-0.715))
# States: (True, False, False, False)
# Vectors: (array([ 0.01538128, -0.01967472, -0.0207544 ,  0.02121121, -0.02764904,
#        -0.02511582]), array([ 0.05749381,  0.0089345 , -0.02192611,  0.00066233,  0.0075525 ,
#        -0.00427635]), array([ 0.05901742,  0.00993264, -0.01278262, -0.02461904, -0.00919676,
#         0.01999201]), array([ 0.05106789,  0.00172871, -0.00447064, -0.01904351, -0.01172233,
#         0.01851044]))
# Prodcuts: (np.float64(0.998), np.float64(0.368), np.float64(-0.891), np.float64(-0.722))
# States: (True, False, False, False)
# Vectors: (array([ 0.01469535, -0.02131683, -0.02000719,  0.01959002, -0.02776444,
#        -0.02428478]), array([ 0.05729723,  0.00885987, -0.02123635,  0.00023556,  0.00834739,
#        -0.00400566]), array([ 0.0594148 ,  0.01000202, -0.01204425, -0.02440712, -0.00871414,
#         0.01970986]), array([ 0.05151677,  0.00192612, -0.00387996, -0.01928321, -0.01202476,
#         0.01815525]))
# Prodcuts: (np.float64(0.999), np.float64(0.302), np.float64(-0.887), np.float64(-0.723))
# States: (True, False, False, False)
# Vectors: (array([ 0.01496831, -0.02000964, -0.02082397,  0.02112415, -0.0278877 ,
#        -0.02532098]), array([ 0.05685091,  0.00889707, -0.02189153,  0.0012989 ,  0.00724465,
#        -0.00464093]), array([ 0.05874175,  0.00988275, -0.01272991, -0.02454618, -0.00908148,
#         0.01975116]), array([ 0.0509488 ,  0.00197053, -0.00440892, -0.01905289, -0.01178312,
#         0.01836586]))
# Prodcuts: (np.float64(0.998), np.float64(0.448), np.float64(-0.893), np.float64(-0.725))
# States: (True, False, False, False)
# Vectors: (array([ 0.01565355, -0.02080941, -0.02040023,  0.01892039, -0.02824032,
#        -0.02445727]), array([ 0.05721352,  0.00993896, -0.02139772, -0.0020684 ,  0.01035172,
#        -0.00289301]), array([ 0.0596838 ,  0.01225454, -0.01192042, -0.02518499, -0.00778979,
#         0.02093418]), array([ 0.05222759,  0.00342447, -0.00390739, -0.01881179, -0.01165587,
#         0.01853306]))
# Prodcuts: (np.float64(0.998), np.float64(0.069), np.float64(-0.884), np.float64(-0.723))
# States: (True, False, False, False)
# Vectors: (array([ 0.01553541, -0.01877767, -0.01997665,  0.02086347, -0.02714062,
#        -0.02467591]), array([ 0.0569298 ,  0.01209778, -0.0204655 , -0.00161293,  0.00763255,
#        -0.0032469 ]), array([ 0.05818936,  0.0125066 , -0.01183209, -0.02409306, -0.00975156,
#         0.01995055]), array([ 0.05112678,  0.00292128, -0.00408871, -0.01708305, -0.01272041,
#         0.01832315]))
# Prodcuts: (np.float64(0.998), np.float64(0.128), np.float64(-0.885), np.float64(-0.683))
# States: (True, False, False, False)
# Vectors: (array([ 0.01516035, -0.01937246, -0.02043296,  0.02027535, -0.02717769,
#        -0.02466883]), array([ 0.05744848,  0.00945407, -0.02077753, -0.00102115,  0.00844473,
#        -0.00292949]), array([ 0.05870122,  0.01072711, -0.01177416, -0.02482805, -0.00879449,
#         0.02048405]), array([ 0.05102247,  0.00247025, -0.00391729, -0.01818398, -0.01205724,
#         0.01843441]))
# Prodcuts: (np.float64(0.998), np.float64(0.148), np.float64(-0.883), np.float64(-0.704))
# States: (True, False, False, False)
# Vectors: (array([ 0.01548296, -0.02066022, -0.02004516,  0.01883829, -0.02833104,
#        -0.02421373]), array([ 0.05722377,  0.01133788, -0.02081158, -0.00287461,  0.0085476 ,
#        -0.00272116]), array([ 0.05940124,  0.01310301, -0.01152982, -0.02572444, -0.00908595,
#         0.02077294]), array([ 0.05210504,  0.00385374, -0.00380697, -0.01914161, -0.01232016,
#         0.01828203]))
# Prodcuts: (np.float64(0.998), np.float64(-0.019), np.float64(-0.889), np.float64(-0.729))
# States: (True, False, False, False)
# Vectors: (array([ 0.01557755, -0.02065861, -0.02048593,  0.02026173, -0.02903759,
#        -0.02437637]), array([ 0.05838415,  0.01133144, -0.02088495, -0.00517756,  0.00668979,
#        -0.00247354]), array([ 0.05916035,  0.01248246, -0.01192137, -0.02650198, -0.01096064,
#         0.02012676]), array([ 0.05186081,  0.00308728, -0.00363942, -0.02059197, -0.0115521 ,
#         0.01859852]))
# Prodcuts: (np.float64(0.997), np.float64(-0.315), np.float64(-0.901), np.float64(-0.748))
# States: (True, False, False, False)
# Vectors: (array([ 0.01508716, -0.02080542, -0.02030013,  0.0182845 , -0.0289802 ,
#        -0.02475014]), array([ 0.05762178,  0.01047766, -0.02100628, -0.00327903,  0.0075106 ,
#        -0.00382955]), array([ 0.05946046,  0.01156801, -0.0116994 , -0.02563423, -0.00966036,
#         0.01971298]), array([ 0.05173859,  0.00264597, -0.00371128, -0.01956758, -0.01130223,
#         0.01813236]))
# Prodcuts: (np.float64(0.998), np.float64(-0.053), np.float64(-0.896), np.float64(-0.737))
# States: (True, False, False, False)
# Vectors: (array([ 0.01605642, -0.02060157, -0.02033007,  0.01968753, -0.028624  ,
#        -0.02510505]), array([ 0.05673069,  0.00872695, -0.02138824,  0.00058407,  0.00868076,
#        -0.00409736]), array([ 0.05916759,  0.01103079, -0.01165515, -0.02538306, -0.00950885,
#         0.02036513]), array([ 0.05185941,  0.00296998, -0.0037483 , -0.01960921, -0.01282519,
#         0.01818163]))
# Prodcuts: (np.float64(0.998), np.float64(0.334), np.float64(-0.887), np.float64(-0.727))
# States: (True, False, False, False)
# Vectors: (array([ 0.01532117, -0.01872426, -0.02075689,  0.02202186, -0.02698004,
#        -0.02579342]), array([ 0.05673188,  0.00911915, -0.02156526,  0.00231826,  0.00756365,
#        -0.00443318]), array([ 0.05840716,  0.00975943, -0.01211688, -0.02470303, -0.01072639,
#         0.02014213]), array([ 0.05093271,  0.00149226, -0.00426164, -0.01737154, -0.01412475,
#         0.01823853]))
# Prodcuts: (np.float64(0.997), np.float64(0.532), np.float64(-0.881), np.float64(-0.666))
# States: (True, True, False, False)
# Vectors: (array([ 0.01199189, -0.01935393, -0.02188005,  0.02378529, -0.01998109,
#        -0.02494039]), array([ 0.04901412,  0.01492226, -0.0258313 ,  0.01905826,  0.03328139,
#        -0.00218964]), array([ 0.05991635,  0.01369464, -0.01368854, -0.01558244, -0.01982141,
#         0.0267128 ]), array([ 0.05297244,  0.00693715, -0.00775675, -0.00304201, -0.02600843,
#         0.01971608]))
# Prodcuts: (np.float64(0.968), np.float64(0.675), np.float64(-0.679), np.float64(-0.279))
# States: (True, True, False, False)
# Vectors: (array([ 0.0135377 , -0.00439924, -0.02184122,  0.0220505 ,  0.01551729,
#        -0.02782083]), array([ 0.01429072,  0.0040549 , -0.02169591,  0.02571139,  0.01578534,
#        -0.02776298]), array([ 0.00906414,  0.00211662, -0.02277812,  0.02829635,  0.01385349,
#        -0.02296314]), array([-0.00054151,  0.00496536, -0.02024351,  0.018049  ,  0.00285035,
#        -0.01892835]))
# Prodcuts: (np.float64(0.83), np.float64(0.959), np.float64(0.843), np.float64(0.706))
# States: (True, True, True, True)
# Vectors: (array([ 0.01631495, -0.0056929 , -0.0207813 ,  0.02659851,  0.02143323,
#        -0.0266853 ]), array([ 0.01620704,  0.00134039, -0.02220222,  0.02990219,  0.02537233,
#        -0.02787753]), array([ 0.00948966, -0.0011822 , -0.02295439,  0.03152299,  0.01849949,
#        -0.02462153]), array([-0.0024907 ,  0.00481951, -0.02069372,  0.01978064,  0.00548071,
#        -0.02035913]))
# Prodcuts: (np.float64(0.74), np.float64(0.859), np.float64(0.769), np.float64(0.644))
# States: (True, True, True, True)
# Vectors: (array([ 0.02279377,  0.01401299, -0.02158694,  0.01455736,  0.05363375,
#        -0.02217076]), array([ 0.01967001,  0.02612168, -0.02132733,  0.0230819 ,  0.05677277,
#        -0.01420731]), array([ 0.01745597,  0.02635962, -0.02042514,  0.02561975,  0.05411863,
#        -0.00557123]), array([ 0.00879666,  0.02245158, -0.01699973,  0.02249908,  0.03114319,
#        -0.00587534]))
# Prodcuts: (np.float64(0.759), np.float64(0.912), np.float64(0.878), np.float64(0.869))
# States: (True, True, True, True)
# Vectors: (array([-1.52238607e-02,  2.09856629e-02, -2.27549784e-02, -1.02519989e-05,
#         3.55181694e-02, -2.52224877e-02]), array([-0.00597894,  0.02144808, -0.01830028, -0.00976729,  0.03741324,
#        -0.01673006]), array([-0.00432521,  0.02028841, -0.01718931, -0.0181241 ,  0.02690959,
#        -0.01023564]), array([-0.00014853,  0.02199376, -0.01447282, -0.01319015,  0.00825059,
#        -0.00851825]))
# Prodcuts: (np.float64(0.878), np.float64(0.961), np.float64(0.873), np.float64(0.657))
# States: (True, True, True, True)
# Vectors: (array([-0.01374406,  0.01697105, -0.02908592, -0.00145942,  0.0361954 ,
#        -0.0324595 ]), array([-0.0070405 ,  0.02191973, -0.02504195, -0.00689977,  0.03288811,
#        -0.02222619]), array([-0.00371391,  0.0224607 , -0.0231056 , -0.01466143,  0.02226633,
#        -0.01251422]), array([ 0.00224078,  0.02354872, -0.02043279, -0.00663471,  0.00619018,
#        -0.01025181]))
# Prodcuts: (np.float64(0.892), np.float64(0.968), np.float64(0.883), np.float64(0.795))
# States: (True, True, True, True)
# Vectors: (array([-0.04038262,  0.06880778, -0.01682995,  0.02939534,  0.00198108,
#        -0.00413895]), array([-0.04515141,  0.0776009 , -0.01809681,  0.03266823, -0.01984781,
#         0.00665823]), array([-0.04252666,  0.07425547, -0.01613509,  0.02973038, -0.03013301,
#         0.01568281]), array([-0.03693044,  0.05723184, -0.01013311,  0.02565914, -0.0333975 ,
#         0.01016377]))
# Prodcuts: (np.float64(-0.404), np.float64(-0.882), np.float64(-0.955), np.float64(-0.993))
# States: (False, False, False, False)
# Vectors: (array([-0.00075972,  0.00433469, -0.03516747, -0.00039285, -0.00812292,
#        -0.04145265]), array([-0.00070918,  0.03728074, -0.03956483, -0.01735926,  0.06632555,
#        -0.01697361]), array([-0.01200223,  0.05780202, -0.03289641, -0.02704132,  0.0588879 ,
#         0.00959376]), array([-0.01854658,  0.05216295, -0.02420482, -0.02420866,  0.02726388,
#         0.00676356]))
# Prodcuts: (np.float64(0.95), np.float64(0.822), np.float64(0.771), np.float64(0.762))
# States: (True, True, True, True)
# Vectors: (array([-0.01259929, -0.05307478, -0.01476384, -0.01024377, -0.05336338,
#        -0.01953558]), array([-0.00673866, -0.05797344, -0.01272064, -0.00909519, -0.06232494,
#        -0.01936143]), array([ 0.00342494, -0.0562076 , -0.01605931, -0.00311482, -0.06130075,
#        -0.01466161]), array([ 0.01388764, -0.0392139 , -0.01708024,  0.00732332, -0.05239004,
#        -0.00733767]))
# Prodcuts: (np.float64(0.996), np.float64(0.996), np.float64(0.993), np.float64(0.95))
# States: (True, True, True, True)
# Vectors: (array([-0.0253669 , -0.010144  , -0.01967553, -0.03339362, -0.02241814,
#        -0.02326461]), array([-0.02436143,  0.03717822, -0.02135107, -0.00121248,  0.01025045,
#        -0.00348417]), array([-0.0394277 ,  0.06331891, -0.01387092,  0.00647354, -0.01460159,
#         0.0174743 ]), array([-0.03703886,  0.04838836, -0.01284063,  0.00895917, -0.02751714,
#         0.00966893]))
# Prodcuts: (np.float64(0.979), np.float64(0.903), np.float64(-0.792), np.float64(-0.941))
# States: (True, True, False, False)
# Vectors: (array([-0.01349217, -0.01141572, -0.02433505, -0.02501112, -0.02822566,
#        -0.02735546]), array([-0.02199465,  0.04170984, -0.02550633, -0.00855339,  0.02944756,
#         0.00035023]), array([-0.03820109,  0.05965292, -0.01817458, -0.00542033, -0.01041347,
#         0.02111264]), array([-0.03801006,  0.0466314 , -0.01598599, -0.00196689, -0.02402729,
#         0.00999625]))
# Prodcuts: (np.float64(0.946), np.float64(0.856), np.float64(-0.452), np.float64(-0.742))
# States: (True, True, False, False)
# Vectors: (array([ 0.01236224,  0.0160408 , -0.03412443, -0.00956577,  0.04450619,
#        -0.03740836]), array([ 0.00876987,  0.02523077, -0.03619948, -0.0092541 ,  0.05479109,
#        -0.03440861]), array([ 0.00128508,  0.02566302, -0.03082847, -0.00452632,  0.0336799 ,
#        -0.02095633]), array([-0.00280797,  0.01322526, -0.02187982, -0.00446981,  0.00400025,
#        -0.01154222]))
# Prodcuts: (np.float64(0.801), np.float64(0.866), np.float64(0.939), np.float64(0.95))
# States: (True, True, True, True)
# Vectors: (array([-0.0264712 , -0.00353575, -0.02057404, -0.03880042, -0.02659881,
#        -0.02392821]), array([-0.0447098 ,  0.05005902, -0.02257983, -0.00307113,  0.02426606,
#        -0.01060802]), array([-0.05171561,  0.06465703, -0.01949465,  0.02618277, -0.0209083 ,
#         0.011665  ]), array([-0.04727477,  0.04961216, -0.01434121,  0.02138102, -0.03143007,
#         0.00912558]))
# Prodcuts: (np.float64(0.907), np.float64(0.843), np.float64(-0.972), np.float64(-0.987))
# States: (True, True, False, False)
# Vectors: (array([ 0.00982541, -0.01657695, -0.02850615,  0.01762158, -0.01087922,
#        -0.03212891]), array([ 0.02072012,  0.00372916, -0.03468638,  0.01461715,  0.03595859,
#        -0.02182797]), array([ 0.00190014,  0.0281328 , -0.02971938, -0.0225746 ,  0.02396244,
#         0.00129645]), array([-0.00439811,  0.02341682, -0.0220753 , -0.01649493,  0.00809646,
#         0.00090287]))
# Prodcuts: (np.float64(0.965), np.float64(0.661), np.float64(0.439), np.float64(0.405))
# States: (True, True, False, False)
# Vectors: (array([ 0.00519919, -0.01700294, -0.02653422,  0.01661783, -0.01982075,
#        -0.03152368]), array([ 0.02122885,  0.01346642, -0.03187293,  0.02167875,  0.01989436,
#        -0.02056229]), array([-0.00336689,  0.04420555, -0.02525806, -0.0339722 ,  0.01633656,
#         0.00445972]), array([-0.00962776,  0.03498286, -0.01824397, -0.02737689,  0.00286877,
#         0.00490115]))
# Prodcuts: (np.float64(0.967), np.float64(0.949), np.float64(0.374), np.float64(0.242))
# States: (True, True, False, False)
# Vectors: (array([-0.04361278,  0.05526686, -0.02060566,  0.00533789,  0.01131552,
#        -0.01427568]), array([-0.05074245,  0.06372488, -0.01906316,  0.00891954, -0.01128161,
#        -0.00143469]), array([-0.04905474,  0.05638051, -0.01908337,  0.00994796, -0.00999922,
#         0.01337665]), array([-0.03792429,  0.04008985, -0.01334355,  0.0081045 , -0.01224303,
#         0.00502351]))
# Prodcuts: (np.float64(0.493), np.float64(-0.946), np.float64(-0.872), np.float64(-0.982))
# States: (False, False, False, False)
# Vectors: (array([ 0.00454187, -0.0171513 , -0.029619  ,  0.01887232, -0.03683996,
#        -0.03565831]), array([ 0.02108091,  0.01707095, -0.03780893,  0.02379048,  0.01932615,
#        -0.02376626]), array([-0.00306416,  0.04760265, -0.02689324, -0.02879548,  0.00710106,
#         0.01002307]), array([-0.01063174,  0.03958547, -0.01795432, -0.02490091, -0.00410777,
#         0.00916761]))
# Prodcuts: (np.float64(0.94), np.float64(0.959), np.float64(0.091), np.float64(-0.052))
# States: (True, True, False, False)
# Vectors: (array([-0.03363699,  0.07633936, -0.01968103, -0.00151235, -0.00605476,
#        -0.01385894]), array([-0.04101759,  0.08658737, -0.0167233 ,  0.00312692, -0.02537555,
#        -0.00079652]), array([-0.04115546,  0.07407683, -0.01571389,  0.00353366, -0.02680814,
#         0.01676933]), array([-0.0311271 ,  0.04831338, -0.01380351,  0.00612861, -0.02243096,
#         0.0062324 ]))
# Prodcuts: (np.float64(-0.106), np.float64(-0.929), np.float64(-0.873), np.float64(-0.956))
# States: (False, False, False, False)
#
# Gra zakonczona!
# Wynik koncowy: Gracz 5 - 8 Komputer

# %%
print("\n=== HISTORIA GRY ===")
for record in game_controller.match_history:
    print(f"Runda {record.round_number}: "
          f"Gracz: {record.player_move.name}, "
          f"Komputer: {record.computer_move.name}, "
          f"Wynik: {record.outcome.name}")
# Out:
# === HISTORIA GRY ===
